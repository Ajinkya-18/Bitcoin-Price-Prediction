# %% [markdown]
# # Bitcoin Price Prediction

# %% [markdown]
# ## Loading Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
df = pd.read_csv('../data/bitcoin_2017_to_2023.csv')

# %%
df.head()
# Out:
#              timestamp      open      high       low     close    volume  \
# 0  2023-08-01 13:19:00  28902.48  28902.49  28902.48  28902.49   4.68658
# 1  2023-08-01 13:18:00  28902.48  28902.49  28902.48  28902.49   4.77589
# 2  2023-08-01 13:17:00  28908.52  28908.53  28902.48  28902.49  11.52263
# 3  2023-08-01 13:16:00  28907.41  28912.74  28907.41  28908.53  15.89610
# 4  2023-08-01 13:15:00  28896.00  28907.42  28893.03  28907.41  37.74657
#
#    quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# 0        1.354538e+05               258                      0.89391
# 1        1.380351e+05               317                      2.24546
# 2        3.330532e+05               451                      2.70873
# 3        4.595556e+05               483                     10.22981
# 4        1.090761e+06               686                     16.50452
#
#    taker_buy_quote_asset_volume
# 0                  25836.224836
# 1                  64899.385195
# 2                  78290.170121
# 3                 295738.166916
# 4                 476955.246611

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3126000 entries, 0 to 3125999
# Data columns (total 10 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   timestamp                     object
#  1   open                          float64
#  2   high                          float64
#  3   low                           float64
#  4   close                         float64
#  5   volume                        float64
#  6   quote_asset_volume            float64
#  7   number_of_trades              int64
#  8   taker_buy_base_asset_volume   float64
#  9   taker_buy_quote_asset_volume  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 238.5+ MB

# %%
df.describe()
# Out:
#                open          high           low         close        volume  \
# count  3.126000e+06  3.126000e+06  3.126000e+06  3.126000e+06  3.126000e+06
# mean   2.008947e+04  2.010217e+04  2.007666e+04  2.008946e+04  5.290800e+01
# std    1.605896e+04  1.606926e+04  1.604871e+04  1.605896e+04  9.774388e+01
# min    2.830000e+03  2.830000e+03  2.817000e+03  2.817000e+03  0.000000e+00
# 25%    7.624747e+03  7.629600e+03  7.620000e+03  7.624798e+03  1.120167e+01
# 50%    1.169999e+04  1.170681e+04  1.169249e+04  1.170000e+04  2.387539e+01
# 75%    2.989957e+04  2.990724e+04  2.989051e+04  2.989957e+04  5.393630e+01
# max    6.900000e+04  6.900000e+04  6.878670e+04  6.900000e+04  5.877775e+03
#
#        quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# count        3.126000e+06      3.126000e+06                 3.126000e+06
# mean         1.155882e+06      1.018583e+03                 2.632231e+01
# std          2.335868e+06      1.817813e+03                 4.972880e+01
# min          0.000000e+00      0.000000e+00                 0.000000e+00
# 25%          1.122335e+05      1.500000e+02                 5.100715e+00
# 50%          3.706467e+05      4.130000e+02                 1.148990e+01
# 75%          1.276762e+06      1.026000e+03                 2.693009e+01
# max          1.459557e+08      1.073150e+05                 3.537453e+03
#
#        taker_buy_quote_asset_volume
# count                  3.126000e+06
# mean                   5.727211e+05
# std                    1.193135e+06
# min                    0.000000e+00
# 25%                    5.125057e+04
# 50%                    1.753695e+05
# 75%                    6.210250e+05
# max                    8.947551e+07

# %%
df.isnull().sum()
# Out:
# timestamp                       0
# open                            0
# high                            0
# low                             0
# close                           0
# volume                          0
# quote_asset_volume              0
# number_of_trades                0
# taker_buy_base_asset_volume     0
# taker_buy_quote_asset_volume    0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %%
plt.figure(figsize=(12,6))
plt.title("Bitcoin Close Price", fontsize=12)
plt.plot(df["close"])
plt.xlabel("Number of Price Points")
plt.ylabel("Price in Dollars")
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
splitted = df['timestamp'].str.split(' ', expand=True)
df['date'] = splitted[0].astype('str')
df['time'] = splitted[1].astype('str')

splitted1 = df['date'].str.split('-', expand=True)
df['year'] = splitted1[0].astype('int')
df['month'] = splitted1[1].astype('int')
df['day'] = splitted1[2].astype('int')

splitted2 = df['time'].str.split(':', expand=True)
df['hour'] = splitted2[0].astype('int')
df['minute'] = splitted2[1].astype('int')

# %%
df['close-open'] = df['close'] - df['open']
df['high-low'] = df['high'] - df['low']
df['wick_length_high'] = df['high'] - df[['open', 'close']].max(axis=1)
df['wick_length_low'] = df[['open', 'close']].min(axis=1) - df['low']
df['buy_ratio'] = df['taker_buy_base_asset_volume'] / df['volume']
df['volume_delta'] = df['volume'] - df['volume'].shift(-1)
df['trade_activity_rate'] = df['number_of_trades'] / df['volume']

df['target'] = np.where(df['close'] > df['close'].shift(-1), 1, 0) # checks if the price went up (1) or down (0)

# %%
# saved the date and time column in separate series for future reference before deleting from the dataframe
# date = pd.Series(df['date'])
# time = pd.Series(df['time'])

# %%
df.drop(['date', 'time', 'timestamp', 'open', 'high', 'low', 'year', 
         'taker_buy_quote_asset_volume', 'quote_asset_volume', 'number_of_trades'], 
        axis=1, inplace=True)

# %%
len(df.columns)
# Out:
# 16

# %%
corr_mat = df.corr(numeric_only=True)

plt.figure(figsize = (15,20))
sns.heatmap(corr_mat, annot = True, cbar=True, fmt='.2f')
plt.savefig('../reports/feature_correlation_matrix.png')

# %%
del splitted, splitted1, splitted2

# %%
df.columns
# Out:
# Index(['close', 'volume', 'taker_buy_base_asset_volume', 'year', 'month',
#        'day', 'hour', 'minute', 'close-open', 'high-low', 'wick_length_high',
#        'wick_length_low', 'buy_ratio', 'volume_delta', 'trade_activity_rate',
#        'target'],
#       dtype='object')

# %%
features = ['close', 'volume', 'taker_buy_base_asset_volume', 'close-open', 
            'high-low', 'wick_length_high', 'wick_length_low', 'buy_ratio', 
            'volume_delta', 'trade_activity_rate']

plt.subplots(figsize=(16,8))

for i, col in enumerate(features):
  plt.subplot(5,2,i+1)
  sns.histplot(df[col], kde=True)

plt.savefig('../reports/feature_values_histograms.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 9
#       7 for i, col in enumerate(features):
#       8   plt.subplot(5,2,i+1)
# ----> 9   sns.histplot(df[col], kde=True)
#      11 plt.savefig('../reports/feature_values_histograms.png')
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\seaborn\distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)
#    1446         **kwargs,
#    1447     )
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\seaborn\distributions.py:571, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     566 if element == "bars":
#     567
#     568     # Use matplotlib bar plotting
#     570     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 571     artists = plot_func(
#     572         hist["edges"],
#     573         hist["heights"] - bottom,
#     574         hist["widths"],
#     575         bottom,
#     576         align="edge",
#     577         **artist_kws,
#     578     )
#     580     for bar in artists:
#     581         if self.data_variable == "x":
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\axes\_axes.py:2660, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2658     else:  # horizontal
#    2659         r.sticky_edges.x.append(l)
# -> 2660     self.add_patch(r)
#    2661     patches.append(r)
#    2663 if xerr is not None or yerr is not None:
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\axes\_base.py:2482, in _AxesBase.add_patch(self, p)
#    2480 if p.get_clip_path() is None:
#    2481     p.set_clip_path(self.patch)
# -> 2482 self._update_patch_limits(p)
#    2483 self._children.append(p)
#    2484 p._remove_method = self._children.remove
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\axes\_base.py:2523, in _AxesBase._update_patch_limits(self, patch)
#    2521     if updatey and patch_trf == self.get_xaxis_transform():
#    2522         updatey = False
# -> 2523 trf_to_data = patch_trf - self.transData
#    2524 xys = trf_to_data.transform(vertices)
#    2525 self.update_datalim(xys, updatex=updatex, updatey=updatey)
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\transforms.py:1450, in Transform.__sub__(self, other)
#    1448 if not isinstance(other, Transform):
#    1449     return NotImplemented
# -> 1450 for remainder, sub_tree in self._iter_break_from_left_to_right():
#    1451     if sub_tree == other:
#    1452         return remainder
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\transforms.py:2385, in CompositeGenericTransform._iter_break_from_left_to_right(self)
#    2384 def _iter_break_from_left_to_right(self):
# -> 2385     for left, right in self._a._iter_break_from_left_to_right():
#    2386         yield left, right + self._b
#    2387     for left, right in self._b._iter_break_from_left_to_right():
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\transforms.py:2385, in CompositeGenericTransform._iter_break_from_left_to_right(self)
#    2384 def _iter_break_from_left_to_right(self):
# -> 2385     for left, right in self._a._iter_break_from_left_to_right():
#    2386         yield left, right + self._b
#    2387     for left, right in self._b._iter_break_from_left_to_right():
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\transforms.py:1365, in Transform._iter_break_from_left_to_right(self)
#    1355 def _iter_break_from_left_to_right(self):
#    1356     """
#    1357     Return an iterator breaking down this transform stack from left to
#    1358     right recursively. If self == ((A, N), A) then the result will be an
#    (...)
#    1363     ``flat_stack[:i], flat_stack[i:]`` where i=0..(n-1).
#    1364     """
# -> 1365     yield IdentityTransform(), self
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\transforms.py:1770, in AffineBase.__init__(self, *args, **kwargs)
#    1769 def __init__(self, *args, **kwargs):
# -> 1770     super().__init__(*args, **kwargs)
#    1771     self._inverted = None
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\transforms.py:110, in TransformNode.__init__(self, shorthand_name)
#     104 pass_through = False
#     105 """
#     106 If pass_through is True, all ancestors will always be
#     107 invalidated, even if 'self' is already invalid.
#     108 """
# --> 110 def __init__(self, shorthand_name=None):
#     111     """
#     112     Parameters
#     113     ----------
#    (...)
#     117         ``str(transform)`` when DEBUG=True.
#     118     """
#     119     self._parents = {}
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x00000243090E0940> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\axes\_base.py:3216, in _AxesBase.draw(self, renderer)
#    3213 if artists_rasterized:
#    3214     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3216 mimage._draw_list_compositing_images(
#    3217     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3219 renderer.close_group('axes')
#    3220 self.stale = False
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\patches.py:641, in Patch.draw(self, renderer)
#     639 transform = self.get_transform()
#     640 tpath = transform.transform_path_non_affine(path)
# --> 641 affine = transform.get_affine()
#     642 self._draw_paths_with_artist_properties(
#     643     renderer,
#     644     [(tpath, affine,
#    (...)
#     647       # transparent, but do if it is None.
#     648       self._facecolor if self._facecolor[3] else None)])
#
# File A:\AI-Projects\tools\miniconda3\envs\stats_ml\lib\site-packages\matplotlib\transforms.py:2436, in CompositeGenericTransform.get_affine(self)
#    2434     return self._b.get_affine()
#    2435 else:
# -> 2436     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2437                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000002431ACB5B40> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt

# %%
plt.subplots(figsize=(16,8))

for i, col in enumerate(features):
  plt.subplot(5, 2, i+1)
  sns.boxplot(df[col])

plt.savefig('../reports/feature_values_barplots.png')

# %%
plt.pie(df['target'].value_counts().values, labels = [0,1], autopct = "%.2f%%")
plt.show()

# %% [markdown]
# ## Feature Selection and Scaling

# %%
X, Y = df.drop(['target'], axis=1), df['target']

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# (2500800, 5) (625200, 5)

# %%
from joblib import dump
with open('../models/fitted_scaler.joblib', 'wb') as f:
    dump(scaler, f)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
lc = LogisticRegression()
knc = KNeighborsClassifier()
dtc = DecisionTreeClassifier()
hgbc = HistGradientBoostingClassifier()

# %%
lc.fit(X_train_scaled, Y_train)
knc.fit(X_train_scaled, Y_train)
dtc.fit(X_train_scaled, Y_train)
hgbc.fit(X_train_scaled, Y_train)
# Out:
# HistGradientBoostingClassifier()

# %% [markdown]
# ## Model Testing

# %%
lc_preds = lc.predict(X_test_scaled)
knc_preds = knc.predict(X_test_scaled)
dtc_preds = dtc.predict(X_test_scaled)
hgbc_preds = hgbc.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_metrics = {}
model_preds = [lc_preds, knc_preds, dtc_preds, hgbc_preds]
model_names = ['Logistic Regression', 'K-Neighbors Classifier', 'Decision Tree Classifier', 
               'HistGradient Boosting Classifier']

accuracy_scores = [accuracy_score(preds, Y_test) for preds in model_preds]

for model, acc in zip(model_names, accuracy_scores):
    accuracy_metrics[model] = round(acc, 4)

# %%
accuracy_metrics
# Out:
# {'Logistic Regression': 0.9323,
#  'K-Neighbors Classifier': 0.9323,
#  'Decision Tree Classifier': 0.9127,
#  'HistGradient Boosting Classifier': 0.9466}

# %%
# from pickle import dump
# with open('../models/k_neighbors_classifier.pkl', 'wb') as f:
#     dump(knc, f)

# %%
# with open('../models/decision_tree_classifier.pkl', 'wb') as f:
#     dump(dtc, f)

# %%
# with open('../models/hist_gradient_boosting_classifier.pkl', 'wb') as f:
#     dump(hgbc, f)

# %%
# with open('../models/logistic_regression.pkl', 'wb') as f:
#     dump(lc, f)

# %%
from sklearn.metrics import confusion_matrix
lc_cm = confusion_matrix(Y_test, lc_preds)
knc_cm = confusion_matrix(Y_test, knc_preds)
dtc_cm = confusion_matrix(Y_test, dtc_preds)
hgbc_cm = confusion_matrix(Y_test, hgbc_preds)

# %%
cm_list = [lc_cm, knc_cm, dtc_cm, hgbc_cm]
plt.subplots(2,2, figsize=(15, 15))

for i, model_cm in enumerate(cm_list):
    plt.subplot(2,2,i+1)
    sns.heatmap(model_cm, annot=True, cbar=True)
    plt.title(model_names[i])

# plt.savefig('../reports/Confusion Matrix of Models.png')
plt.show()
