# %% [markdown]
# # Bitcoin Price Prediction

# %% [markdown]
# ## Loading Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
df = pd.read_csv('../data/bitcoin_2017_to_2023.csv')

# %%
df.head()
# Out:
#              timestamp      open      high       low     close    volume  \
# 0  2023-08-01 13:19:00  28902.48  28902.49  28902.48  28902.49   4.68658
# 1  2023-08-01 13:18:00  28902.48  28902.49  28902.48  28902.49   4.77589
# 2  2023-08-01 13:17:00  28908.52  28908.53  28902.48  28902.49  11.52263
# 3  2023-08-01 13:16:00  28907.41  28912.74  28907.41  28908.53  15.89610
# 4  2023-08-01 13:15:00  28896.00  28907.42  28893.03  28907.41  37.74657
#
#    quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# 0        1.354538e+05               258                      0.89391
# 1        1.380351e+05               317                      2.24546
# 2        3.330532e+05               451                      2.70873
# 3        4.595556e+05               483                     10.22981
# 4        1.090761e+06               686                     16.50452
#
#    taker_buy_quote_asset_volume
# 0                  25836.224836
# 1                  64899.385195
# 2                  78290.170121
# 3                 295738.166916
# 4                 476955.246611

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3126000 entries, 0 to 3125999
# Data columns (total 10 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   timestamp                     object
#  1   open                          float64
#  2   high                          float64
#  3   low                           float64
#  4   close                         float64
#  5   volume                        float64
#  6   quote_asset_volume            float64
#  7   number_of_trades              int64
#  8   taker_buy_base_asset_volume   float64
#  9   taker_buy_quote_asset_volume  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 238.5+ MB

# %%
df.describe()
# Out:
#                open          high           low         close        volume  \
# count  3.126000e+06  3.126000e+06  3.126000e+06  3.126000e+06  3.126000e+06
# mean   2.008947e+04  2.010217e+04  2.007666e+04  2.008946e+04  5.290800e+01
# std    1.605896e+04  1.606926e+04  1.604871e+04  1.605896e+04  9.774388e+01
# min    2.830000e+03  2.830000e+03  2.817000e+03  2.817000e+03  0.000000e+00
# 25%    7.624747e+03  7.629600e+03  7.620000e+03  7.624798e+03  1.120167e+01
# 50%    1.169999e+04  1.170681e+04  1.169249e+04  1.170000e+04  2.387539e+01
# 75%    2.989957e+04  2.990724e+04  2.989051e+04  2.989957e+04  5.393630e+01
# max    6.900000e+04  6.900000e+04  6.878670e+04  6.900000e+04  5.877775e+03
#
#        quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# count        3.126000e+06      3.126000e+06                 3.126000e+06
# mean         1.155882e+06      1.018583e+03                 2.632231e+01
# std          2.335868e+06      1.817813e+03                 4.972880e+01
# min          0.000000e+00      0.000000e+00                 0.000000e+00
# 25%          1.122335e+05      1.500000e+02                 5.100715e+00
# 50%          3.706467e+05      4.130000e+02                 1.148990e+01
# 75%          1.276762e+06      1.026000e+03                 2.693009e+01
# max          1.459557e+08      1.073150e+05                 3.537453e+03
#
#        taker_buy_quote_asset_volume
# count                  3.126000e+06
# mean                   5.727211e+05
# std                    1.193135e+06
# min                    0.000000e+00
# 25%                    5.125057e+04
# 50%                    1.753695e+05
# 75%                    6.210250e+05
# max                    8.947551e+07

# %%
df.isnull().sum()
# Out:
# timestamp                       0
# open                            0
# high                            0
# low                             0
# close                           0
# volume                          0
# quote_asset_volume              0
# number_of_trades                0
# taker_buy_base_asset_volume     0
# taker_buy_quote_asset_volume    0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %%
plt.figure(figsize=(12,6))
plt.title("Bitcoin Close Price", fontsize=12)
plt.plot(df["close"])
plt.xlabel("Number of Price Points")
plt.ylabel("Price in Dollars")
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
splitted = df['timestamp'].str.split(' ', expand=True)
df['date'] = splitted[0].astype('str')
df['time'] = splitted[1].astype('str')

splitted1 = df['date'].str.split('-', expand=True)
df['year'] = splitted1[0].astype('int')
df['month'] = splitted1[1].astype('int')
df['day'] = splitted1[2].astype('int')

splitted2 = df['time'].str.split(':', expand=True)
df['hour'] = splitted2[0].astype('int')
df['minute'] = splitted2[1].astype('int')

# %%
df['close-open'] = df['close'] - df['open']
df['high-low'] = df['high'] - df['low']
df['wick_length_high'] = df['high'] - df[['open', 'close']].max(axis=1)
df['wick_length_low'] = df[['open', 'close']].min(axis=1) - df['low']
df['buy_ratio'] = df['taker_buy_base_asset_volume'] / df['volume']
df['volume_delta'] = df['volume'] - df['volume'].shift(-1)
df['trade_activity_rate'] = df['number_of_trades'] / df['volume']

df['target'] = np.where(df['close'] > df['close'].shift(-1), 1, 0) # checks if the price went up (1) or down (0)

# %%
# saved the date and time column in separate series for future reference before deleting from the dataframe
# date = pd.Series(df['date'])
# time = pd.Series(df['time'])

# %%
df.drop(['date', 'time', 'timestamp', 'open', 'high', 'low', 'year', 
         'taker_buy_quote_asset_volume', 'quote_asset_volume', 'number_of_trades'], 
        axis=1, inplace=True)

# %%
len(df.columns)
# Out:
# 15

# %%
corr_mat = df.corr(numeric_only=True)

plt.figure(figsize = (15,20))
sns.heatmap(corr_mat, annot = True, cbar=True, fmt='.2f')
plt.savefig('../reports/feature_correlation_matrix.png')

# %%
del splitted, splitted1, splitted2

# %%
df.columns
# Out:
# Index(['close', 'volume', 'taker_buy_base_asset_volume', 'month', 'day',
#        'hour', 'minute', 'close-open', 'high-low', 'wick_length_high',
#        'wick_length_low', 'buy_ratio', 'volume_delta', 'trade_activity_rate',
#        'target'],
#       dtype='object')

# %%
df = df.astype(np.float32)

# %%
features = ['close', 'volume', 'taker_buy_base_asset_volume', 'close-open', 
            'high-low', 'wick_length_high', 'wick_length_low', 'buy_ratio', 
            'volume_delta', 'trade_activity_rate']

plt.subplots(figsize=(14,16))

for i, col in enumerate(features):
  plt.subplot(5,2,i+1)
  sns.histplot(df[col], kde=False, bins=100)

plt.tight_layout()
plt.savefig('../reports/feature_values_histograms.png')

# %%
plt.subplots(figsize=(14,16))

for i, col in enumerate(features):
  plt.subplot(5, 2, i+1)
  sns.boxplot(x=df[col])

plt.tight_layout()
plt.savefig('../reports/feature_values_barplots.png')

# %%
len(df.loc[df['trade_activity_rate'] > 150])
# Out:
# 2283

# %%
df = df.drop(df[df['close'] > 62000].index, axis=0)
df = df.drop(df[df['volume'] > 300].index, axis=0)
df = df.drop(df[df['taker_buy_base_asset_volume'] > 150].index, axis=0)
df = df.drop(df[(df['close-open'] > 100) | (df['close-open'] < -100)].index, axis=0)
df = df.drop(df[(df['high-low'] > 150)].index, axis=0)
df = df.drop(df[(df['wick_length_high'] > 50)].index, axis=0)
df = df.drop(df[(df['wick_length_low'] > 50)].index, axis=0)
df = df.drop(df[(df['volume_delta'] < -250) | (df['volume_delta'] > 250)].index, axis=0)
df = df.drop(df[df['trade_activity_rate'] > 150].index, axis=0)

# %%
df.shape
# Out:
# (2899281, 15)

# %%
plt.subplots(figsize=(14,16))

for i, col in enumerate(features):
  plt.subplot(5, 2, i+1)
  sns.boxplot(x=df[col])

plt.tight_layout()
plt.savefig('../reports/feature_barplots_after_outlier_removal.png')

# %%
plt.pie(df['target'].value_counts().values, labels = [0,1], autopct = "%.2f%%")
plt.show()

# %% [markdown]
# ## Feature Selection and Scaling

# %%
df.dropna(inplace=True)

# %%
X, Y = df.drop(['target'], axis=1), df['target']

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
scaler = RobustScaler()
scaler.set_output(transform='pandas')

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
estimator_lr = LogisticRegression(penalty='l1', C=1.0, class_weight='balanced', n_jobs=5, 
                                  random_state=42, solver='saga', max_iter=1000, verbose=1)

estimator_rfc  = RandomForestClassifier(n_estimators=80, max_depth=8, min_samples_split=100, 
                                        min_samples_leaf=50, bootstrap=True, oob_score=True, 
                                        n_jobs=5, random_state=42, verbose=1, class_weight='balanced')

cv = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)

rfecv_lr = RFECV(estimator=estimator_lr, step=1, min_features_to_select=10, cv=cv, 
                 scoring='f1', verbose=2, n_jobs=5, importance_getter='auto')
rfecv_lr.set_output(transform='pandas')

rfecv_rfc = RFECV(estimator=estimator_rfc, step=1, min_features_to_select=10, cv=cv, 
                 scoring='f1', verbose=2, n_jobs=5, importance_getter='auto')
rfecv_rfc.set_output(transform='pandas')
# Out:
# RFECV(cv=StratifiedKFold(n_splits=6, random_state=42, shuffle=True),
#       estimator=RandomForestClassifier(class_weight='balanced', max_depth=8,
#                                        min_samples_leaf=50,
#                                        min_samples_split=100, n_estimators=80,
#                                        n_jobs=5, oob_score=True,
#                                        random_state=42, verbose=1),
#       min_features_to_select=10, n_jobs=5, scoring='f1', verbose=2)

# %%
rfecv_lr.fit(x_train_scaled, y_train)
# Out:
# Fitting estimator with 14 features.
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# convergence after 12 epochs took 17 seconds
# Fitting estimator with 13 features.
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# convergence after 12 epochs took 17 seconds
# Fitting estimator with 12 features.
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# convergence after 12 epochs took 17 seconds
# Fitting estimator with 11 features.
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# convergence after 12 epochs took 16 seconds
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# convergence after 12 epochs took 16 seconds
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# convergence after 12 epochs took 17 seconds
# RFECV(cv=StratifiedKFold(n_splits=6, random_state=42, shuffle=True),
#       estimator=LogisticRegression(class_weight='balanced', max_iter=1000,
#                                    n_jobs=5, penalty='l1', random_state=42,
#                                    solver='saga', verbose=1),
#       min_features_to_select=10, n_jobs=5, scoring='f1', verbose=2)

# %%
rfecv_lr.ranking_
# Out:
# array([1, 1, 1, 4, 3, 2, 5, 1, 1, 1, 1, 1, 1, 1])

# %%
rfecv_lr.n_features_
# Out:
# np.int64(10)

# %%
rfecv_rfc.fit(x_train, y_train)
# Out:
# Fitting estimator with 14 features.
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   49.4s
# [Parallel(n_jobs=5)]: Done  80 out of  80 | elapsed:  1.6min finished
# Fitting estimator with 13 features.
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=5)]: Done  80 out of  80 | elapsed:  1.6min finished
# Fitting estimator with 12 features.
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=5)]: Done  80 out of  80 | elapsed:  1.7min finished
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=5)]: Done  80 out of  80 | elapsed:  1.7min finished
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=5)]: Done  80 out of  80 | elapsed:  1.7min finished
# RFECV(cv=StratifiedKFold(n_splits=6, random_state=42, shuffle=True),
#       estimator=RandomForestClassifier(class_weight='balanced', max_depth=8,
#                                        min_samples_leaf=50,
#                                        min_samples_split=100, n_estimators=80,
#                                        n_jobs=5, oob_score=True,
#                                        random_state=42, verbose=1),
#       min_features_to_select=10, n_jobs=5, scoring='f1', verbose=2)

# %%
rfecv_rfc.ranking_
# Out:
# array([1, 1, 1, 1, 2, 3, 4, 1, 1, 1, 1, 1, 1, 1])

# %%
rfecv_rfc.n_features_
# Out:
# np.int64(11)

# %%
from joblib import dump
with open('../models/rfecv_lr.joblib', 'wb') as f:
    dump(rfecv_lr, f)

# %%
from joblib import dump
with open('../models/fitted_scaler.joblib', 'wb') as f:
    dump(scaler, f)

# %%
from joblib import dump
with open('../models/rfecv_rfc.joblib', 'wb') as f:
    dump(rfecv_rfc, f)

# %%
x_train_new = rfecv_rfc.transform(x_train)

# %%
x_test_new = rfecv_rfc.transform(x_test)

# %%
rob_scaler = RobustScaler()
rob_scaler.set_output(transform='pandas')

x_train_new_scaled = rob_scaler.fit_transform(x_train_new)
x_test_new_scaled = rob_scaler.transform(x_test_new)

# %%
from joblib import dump
with open('../models/rob_scaler.joblib', 'wb') as f:
    dump(rob_scaler, f)

# %%
x_train_new_scaled.shape
# Out:
# (1926529, 11)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier

# %%
lc = LogisticRegression(penalty='l2', tol=0.0001, C=1.0, class_weight='balanced', 
                        random_state=42, solver='saga', max_iter=1000, verbose=1, n_jobs=5)

hgbc = HistGradientBoostingClassifier(loss='log_loss', learning_rate=0.1, max_iter=200, 
                                      max_leaf_nodes=31, max_depth=10, min_samples_leaf=100, 
                                      max_features=1.0, max_bins=255, categorical_features='from_dtype', 
                                      early_stopping='auto', scoring='f1', validation_fraction=0.2, 
                                      n_iter_no_change=10, tol=1e-07, verbose=1, random_state=42, 
                                      class_weight='balanced')

rfc = RandomForestClassifier(n_estimators=150, max_depth=10, min_samples_split=200, min_samples_leaf=100, 
                             max_features='sqrt', bootstrap=True, oob_score=True, n_jobs=5, 
                             random_state=42, verbose=1, class_weight='balanced')

# %%
lc.fit(x_train_new_scaled, y_train)
# Out:
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# convergence after 12 epochs took 19 seconds
# LogisticRegression(class_weight='balanced', max_iter=1000, n_jobs=5,
#                    random_state=42, solver='saga', verbose=1)

# %%
hgbc.fit(x_train_new_scaled, y_train)
# Out:
# Binning 0.136 GB of training data: 0.414 s
# Binning 0.034 GB of validation data: 0.064 s
# Fitting gradient boosted rounds:
# Fit 11 trees in 5.765 s, (341 total leaves)
# Time spent computing histograms: 0.743s
# Time spent finding best splits:  0.029s
# Time spent applying splits:      0.225s
# Time spent predicting:           0.075s
# HistGradientBoostingClassifier(class_weight='balanced', max_depth=10,
#                                max_iter=200, min_samples_leaf=100,
#                                random_state=42, scoring='f1',
#                                validation_fraction=0.2, verbose=1)

# %%
rfc.fit(x_train_new_scaled, y_train)
# Out:
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=5)]: Done 150 out of 150 | elapsed:  4.4min finished
# RandomForestClassifier(class_weight='balanced', max_depth=10,
#                        min_samples_leaf=100, min_samples_split=200,
#                        n_estimators=150, n_jobs=5, oob_score=True,
#                        random_state=42, verbose=1)

# %% [markdown]
# ## Model Testing

# %%
lc_preds = lc.predict(x_test_new_scaled)
hgbc_preds = hgbc.predict(x_test_new_scaled)
rfc_preds = rfc.predict(x_test_new_scaled)
# Out:
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=5)]: Done 150 out of 150 | elapsed:    3.0s finished

# %%
from sklearn.metrics import accuracy_score, f1_score

# %%
accuracy_metrics = {}
model_preds = [lc_preds, hgbc_preds, rfc_preds]
model_names = ['Logistic Regression', 'HistGradient Boosting Classifier', 'RandomForestClassifier']

accuracy_scores = [accuracy_score(preds, y_test) for preds in model_preds]
f1_scores = [f1_score(preds, y_test) for preds in model_preds]

for model, acc, f1 in zip(model_names, accuracy_scores, f1_scores):
    accuracy_metrics[model] = [{'Accuracy: ': round(acc*100, 2), 'F1: ': round(f1, 2)}]

# %%
accuracy_metrics
# Out:
# {'Logistic Regression': [{'Accuracy: ': 92.57, 'F1: ': 0.92}],
#  'HistGradient Boosting Classifier': [{'Accuracy: ': 94.34, 'F1: ': 0.94}],
#  'RandomForestClassifier': [{'Accuracy: ': 94.36, 'F1: ': 0.94}]}

# %%
from joblib import dump

# %%
with open('../models/LogisticRegression.joblib', 'wb') as f:
    dump(lc, f)

# %%
with open('../models/HistGradientBoostingClassifier.joblib', 'wb') as f:
    dump(hgbc, f)

# %%
with open('../models/RandomForestClassifier.joblib', 'wb') as f:
    dump(rfc, f)

# %%
from sklearn.metrics import confusion_matrix
lc_cm = confusion_matrix(y_test, lc_preds)
hgbc_cm = confusion_matrix(y_test, hgbc_preds)
rfc_cm = confusion_matrix(y_test, rfc_preds)

# %%
np.shape(lc_cm)
# Out:
# (2, 2)

# %%
cm_list = [lc_cm, hgbc_cm, rfc_cm]

plt.figure(figsize=(10, 20))

for i, cm in enumerate(cm_list):
    plt.subplot(3,1,i+1)
    sns.heatmap(cm, annot=True, cbar=True)
    plt.title(model_names[i])
    plt.xlabel('Actual')
    plt.ylabel('Predicted')

plt.savefig('../reports/Confusion Matrix of Models.png')

# %%
from sklearn.metrics import precision_recall_curve, auc, roc_curve, PrecisionRecallDisplay, roc_auc_score

# %%
y_scores_lc = lc.predict_proba(x_test_new_scaled)[:, 1]
y_scores_rfc = rfc.predict_proba(x_test_new_scaled)[:, 1]
y_scores_hgbc = hgbc.predict_proba(x_test_new_scaled)[:, 1]
# Out:
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=5)]: Done 150 out of 150 | elapsed:    3.0s finished

# %%
precision_lc, recall_lc, thresholds = precision_recall_curve(y_true=y_test, y_score=y_scores_lc, pos_label=1)
precision_rfc, recall_rfc, thresholds = precision_recall_curve(y_true=y_test, y_score=y_scores_rfc, pos_label=1)
precision_hgbc, recall_hgbc, thresholds = precision_recall_curve(y_true=y_test, y_score=y_scores_hgbc, pos_label=1)

# %%
fpr_lc, tpr_lc, thresholds = roc_curve(y_true=y_test, y_score=y_scores_lc, pos_label=1)
fpr_hgbc, tpr_hgbc, thresholds = roc_curve(y_true=y_test, y_score=y_scores_hgbc, pos_label=1)
fpr_rfc, tpr_rfc, thresholds = roc_curve(y_true=y_test, y_score=y_scores_rfc, pos_label=1)

# %%
auc_lc = auc(fpr_lc, tpr_lc)
auc_rfc = auc(fpr_rfc, tpr_rfc)
auc_hgbc = auc(fpr_hgbc, tpr_hgbc)

# %%
plt.figure(figsize=(6,6))
plt.plot(fpr_lc, tpr_lc, color='red', lw=2, label=f'ROC Curve-LR: AUC={auc_lc:.2f}')
plt.plot(fpr_rfc, tpr_rfc, color='blue', lw=2, label=f'ROC Curve-RFC: AUC={auc_rfc:.2f}')
plt.plot(fpr_hgbc, tpr_hgbc, color='green', lw=2, label=f'ROC Curve-HGBC: AUC={auc_hgbc:.2f}')
plt.plot([0,1], [0,1], color='black', linestyle='--', label='Random Guess')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend(loc='lower right')
plt.grid(alpha=0.35)
plt.tight_layout()
plt.savefig('../reports/ROC_Curves.png')

# %%
plt.figure(figsize=(6,6))
plt.plot(recall_lc, precision_lc, color='red', lw=2, label=f'Precision-Recall Curve - LR: AUC={auc_lc:.2f}')
plt.plot(recall_rfc, precision_rfc, color='blue', lw=2, label=f'Precision-Recall Curve - RFC: AUC={auc_rfc:.2f}')
plt.plot(recall_hgbc, precision_hgbc, color='green', lw=2, label=f'Precision-Recall Curve - HGBC: AUC={auc_hgbc:.2f}')
plt.plot([0,1], [0,1], color='black', linestyle='--', label='Random Guess')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc='lower left')
plt.grid(alpha=0.35)
plt.tight_layout()
plt.savefig('../reports/Precision_Recall_Curves.png')

# %% [markdown]
# ## Model Inference

# %%
from collections import defaultdict
inf_data = defaultdict(tuple)

for col in df.columns:
    inf_data[col] = (min(df[col]), max(df[col]))

# %%
inf_data
# Out:
# defaultdict(tuple,
#             {'timestamp': ('2017-08-17 04:00:00', '2023-08-01 13:19:00'),
#              'open': (2830.0, 69000.0),
#              'high': (2830.0, 69000.0),
#              'low': (2817.0, 68786.7),
#              'close': (2817.0, 69000.0),
#              'volume': (0.0, 5877.77545),
#              'quote_asset_volume': (0.0, 145955668.3328495),
#              'number_of_trades': (0, 107315),
#              'taker_buy_base_asset_volume': (0.0, 3537.45296),
#              'taker_buy_quote_asset_volume': (0.0, 89475505.03325081)})

# %%
from datetime import datetime
timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
timestamp
# Out:
# '2025-07-21 21:48:09'

# %%
len(df.columns)
# Out:
# 10
